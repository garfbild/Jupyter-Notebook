# %%
import numpy as np
import pandas as pd

data = pd.read_csv("Jan_2020_ontime.csv")
print(type(data))
data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (607346, 22)

# %%
pd.set_option("display.max.columns", None)
data.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0             1            3                EV                  20366
# 1             1            3                EV                  20366
# 2             1            3                EV                  20366
# 3             1            3                EV                  20366
# 4             1            3                EV                  20366
#
#   OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0         EV   N48901               4397              13930
# 1         EV   N16976               4401              15370
# 2         EV   N12167               4404              11618
# 3         EV   N14902               4405              10781
# 4         EV   N606UX               4407              14524
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID DEST  \
# 0                1393007    ORD            11977              1197705  GRB
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607346 entries, 0 to 607345
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   DAY_OF_MONTH           607346 non-null  int64
#  1   DAY_OF_WEEK            607346 non-null  int64
#  2   OP_UNIQUE_CARRIER      607346 non-null  object
#  3   OP_CARRIER_AIRLINE_ID  607346 non-null  int64
#  4   OP_CARRIER             607346 non-null  object
#  5   TAIL_NUM               606648 non-null  object
#  6   OP_CARRIER_FL_NUM      607346 non-null  int64
#  7   ORIGIN_AIRPORT_ID      607346 non-null  int64
#  8   ORIGIN_AIRPORT_SEQ_ID  607346 non-null  int64
#  9   ORIGIN                 607346 non-null  object
#  10  DEST_AIRPORT_ID        607346 non-null  int64
#  11  DEST_AIRPORT_SEQ_ID    607346 non-null  int64
#  12  DEST                   607346 non-null  object
#  13  DEP_TIME               600682 non-null  float64
# ...

# %%
data.describe()
# Out:
#         DAY_OF_MONTH    DAY_OF_WEEK  OP_CARRIER_AIRLINE_ID  OP_CARRIER_FL_NUM  \
# count  607346.000000  607346.000000          607346.000000      607346.000000
# mean       16.014354       3.955735           19994.137492        2622.365261
# std         8.990719       1.910205             375.754232        1822.545302
# min         1.000000       1.000000           19393.000000           1.000000
# 25%         8.000000       2.000000           19790.000000        1070.000000
# 50%        16.000000       4.000000           19977.000000        2177.000000
# 75%        24.000000       5.000000           20378.000000        4108.000000
# max        31.000000       7.000000           20452.000000        6860.000000
#
#        ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  DEST_AIRPORT_ID  \
# count      607346.000000           6.073460e+05    607346.000000
# mean        12657.389167           1.265743e+06     12657.196320
# std          1524.407203           1.524405e+05      1524.279269
# ...

# %%
data.describe(include=np.object)
# Out:
#        OP_UNIQUE_CARRIER OP_CARRIER TAIL_NUM  ORIGIN    DEST DEP_TIME_BLK
# count             607346     607346   606648  607346  607346       607346
# unique                17         17     5444     351     350           19
# top                   WN         WN   N488HA     ATL     ATL    0600-0659
# freq              109770     109770      333   32190   32187        44275

# %%
dataCopy = data.copy()
dataCopy.shape
# Out:
# (607346, 22)

# %%
dataCopy = dataCopy.drop("Unnamed: 21",axis = 1)

# %%
print(dataCopy.isnull().sum())
# Out:
# DAY_OF_MONTH                0
# DAY_OF_WEEK                 0
# OP_UNIQUE_CARRIER           0
# OP_CARRIER_AIRLINE_ID       0
# OP_CARRIER                  0
# TAIL_NUM                  698
# OP_CARRIER_FL_NUM           0
# ORIGIN_AIRPORT_ID           0
# ORIGIN_AIRPORT_SEQ_ID       0
# ORIGIN                      0
# DEST_AIRPORT_ID             0
# DEST_AIRPORT_SEQ_ID         0
# DEST                        0
# DEP_TIME                 6664
# DEP_DEL15                6699
# DEP_TIME_BLK                0
# ARR_TIME                 7075
# ARR_DEL15                8078
# CANCELLED                   0
# DIVERTED                    0
# DISTANCE                    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(data.isnull(), cbar = False, cmap = 'viridis')
plt.show()

# %%
dataCopy = dataCopy.dropna()
dataCopy.shape
# Out:
# (599268, 21)

# %%
print(dataCopy.isnull().sum())
# Out:
# DAY_OF_MONTH             0
# DAY_OF_WEEK              0
# OP_UNIQUE_CARRIER        0
# OP_CARRIER_AIRLINE_ID    0
# OP_CARRIER               0
# TAIL_NUM                 0
# OP_CARRIER_FL_NUM        0
# ORIGIN_AIRPORT_ID        0
# ORIGIN_AIRPORT_SEQ_ID    0
# ORIGIN                   0
# DEST_AIRPORT_ID          0
# DEST_AIRPORT_SEQ_ID      0
# DEST                     0
# DEP_TIME                 0
# DEP_DEL15                0
# DEP_TIME_BLK             0
# ARR_TIME                 0
# ARR_DEL15                0
# CANCELLED                0
# DIVERTED                 0
# DISTANCE                 0
# dtype: int64

# %%
sns.heatmap(dataCopy.isnull(), cbar = False, cmap = 'viridis')
plt.show()

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(dataCopy['DEP_DEL15'], dataCopy['ARR_DEL15'])
print("correlation:",r_value)
print("determination:",r_value**2)
# Out:
# correlation: 0.7112567622506071
# determination: 0.5058861818472166

# %%
print(dataCopy['OP_UNIQUE_CARRIER'].unique())
# Out:
# ['EV' 'WN' 'MQ' 'B6' 'HA' 'AA' 'F9' 'YX' '9E' 'YV' 'OH' 'NK' 'DL' 'OO'
#  'UA' 'G4' 'AS']

# %%
from scipy import stats
stats.f_oneway(dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'EV'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'WN'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'MQ'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'B6'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'HA'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'AA'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'F9'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'YX'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == '9E'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'YV'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'OH'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'NK'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'DL'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'OO'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'UA'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'G4'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'AS'])
# Out:
# F_onewayResult(statistic=402.559335658968, pvalue=0.0)

# %%
from scipy import stats
stats.levene(dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'EV'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'WN'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'MQ'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'B6'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'HA'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'AA'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'F9'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'YX'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == '9E'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'YV'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'OH'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'NK'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'DL'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'OO'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'UA'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'G4'],
               dataCopy['ARR_DEL15'][dataCopy['OP_UNIQUE_CARRIER'] == 'AS'])
# Out:
# LeveneResult(statistic=402.55933565896805, pvalue=0.0)

# %%
dataCopy[['OP_UNIQUE_CARRIER','ARR_DEL15']].groupby('OP_UNIQUE_CARRIER').mean()
# Out:
#                    ARR_DEL15
# OP_UNIQUE_CARRIER
# 9E                  0.109562
# AA                  0.150360
# AS                  0.211375
# B6                  0.149263
# DL                  0.105833
# EV                  0.154298
# F9                  0.145793
# G4                  0.200705
# HA                  0.098076
# MQ                  0.196923
# NK                  0.134656
# OH                  0.215259
# OO                  0.153840
# UA                  0.129844
# WN                  0.095824
# YV                  0.178447
# YX                  0.118920
